# %% [markdown]
# # 04 Working Capital Analysis
#
# Review AR/AP aging, overdue balances, and DSO/DPO/DIO/CCC estimates.

# %%
from pathlib import Path
import sys


def find_project_root(start: Path) -> Path:
    for path in [start, *start.parents]:
        if (path / "src").is_dir() and (path / "data").is_dir():
            return path
    raise RuntimeError("Open the repository root in VS Code or run this notebook from inside the project folder.")


PROJECT_ROOT = find_project_root(Path.cwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import SAMPLE_DATA_DIR
from src.load_data import load_all_raw_data
from src.clean_data import clean_all
from src.build_features import build_reporting_tables
from src.kpis import build_working_capital_kpis

cleaned = clean_all(load_all_raw_data(SAMPLE_DATA_DIR))
tables = build_reporting_tables(cleaned)
working_capital = build_working_capital_kpis(cleaned['fact_sales'], cleaned['fact_inventory'], cleaned['fact_ar'], cleaned['fact_ap'])
working_capital.T

# %%
tables['top_customers_overdue_ar'].head(10)
